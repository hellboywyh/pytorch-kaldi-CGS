# %%
import numpy as np
import matplotlib.pyplot as plt 
b08b08_k04_n16_pattern = np.load("./b08b08_k04_n16_pattern.npy")
plt.figure(figsize=(40,50))
plt.imshow(np.concatenate(np.split(b08b08_k04_n16_pattern,16,0),1)) 
plt.show()
print("WER:21.9%")
# Out:
# WER:21.9%

# %%
b08b08_k04_n16_pattern_v1 = np.load("./b08b08_k04_n16_pattern_v1.npy")
plt.figure(figsize=(40,50))
plt.imshow(np.concatenate(np.split(b08b08_k04_n16_pattern_v1,16,0),1)) 
plt.show()
print("WER:21.2%")
# Out:
# WER:21.2%

# %%
b08b08_k04_n16_pattern_v2 = np.load("./b08b08_k04_n16_pattern_v2.npy")
plt.figure(figsize=(40,50))
plt.imshow(np.concatenate(np.split(b08b08_k04_n16_pattern_v2,16,0),1)) 
plt.show()
print("WER:21.7%")
# Out:
# WER:21.7%
